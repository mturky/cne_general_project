# %%
import pandas as pd

# %%
s2024 = pd.read_excel(r"S:\26.04.26 Turky\2024.xlsx")
s2026 = pd.read_excel(r"S:\26.04.26 Turky\2024.xlsx")

# %%
s2024.columns
# Out:
# Index(['Customer Number', 'Customer Type', 'Entity', 'Contract Number',
#        'End Date', 'Plan', 'Status', 'Decoder', 'Smart Card',
#        'Next Billing Date', 'Billing Cycle', 'Customer Balance'],
#       dtype='object')

# %%
common2024 = s2024.loc[s2024['Customer Number'].isin(s2026['Customer Number'])]
common2026 = s2026.loc[s2026['Customer Number'].isin(s2024['Customer Number'])]

# %%
common2026
# Out:
#         Customer Number             Customer Type            Entity  \
# 0                264696            CNE Subscriber   CNE Head office
# 1                273830  beIN Quartar Installment   CNE Head office
# 2                331333            BeIN sports CC   CNE Head office
# 3                342793            BeIN sports CC   CNE Head office
# 4                373610  beIN Quartar Installment   CNE Head office
# ...                 ...                       ...               ...
# 207614         19169113  beIN Quartar Installment  beIN Alex Roshdy
# 207615         19169114            CNE Subscriber  beIN Alex Roshdy
# 207616         19169116  beIN Quartar Installment         beIN Alex
# 207617         19169117            CNE Subscriber          Eloubour
# 207618         19169118  beIN Quartar Installment  beIN Alex Roshdy
#
#         Contract Number   End Date          Plan  Status    Decoder  \
# 0               3147672 2025-06-21  Premium 2024  Active  296475292
# ...

# %%
common2024.to_csv(r'S:\26.04.26 Turky\common2024.csv', index=False)
common2026.to_csv(r'S:\26.04.26 Turky\common2026.csv', index=False)
