# %%
import pandas as pd

# %%
bein = pd.read_csv(r"S:\17.08.26\30755782_BEINDATANEWRPT.CSV", dtype='str')

# %%
sc = pd.read_excel(r"C:\Users\mturky\Desktop\SC.xlsx", dtype='str')

# %%
merge = bein.loc[bein['Smart Card'].isin(sc['sc'])]

# %%
sc.shape
# Out:
# (40, 1)

# %%
merge[['Smart Card','Customer Number']].drop_duplicates().to_csv('sc to sub.csv', index=False)
