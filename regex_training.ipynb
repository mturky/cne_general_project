# %%
s = " FT25104K4FCK - IPN Inward - PayerMobNo:00201001181112 Payer Name: RAOUF MOHAMED SALAH EL Living Expenses - Total Fees: 0  ac0dcd1b-6b16-4bab-81ce-0232c9acfa76-CR "

# %%
import re

e = re.search(r'\w{8}-\w{4}-\w{4}-\w{4}-.+',s)

print(e.group())
# Out:
# ac0dcd1b-6b16-4bab-81ce-0232c9acfa76-CR
