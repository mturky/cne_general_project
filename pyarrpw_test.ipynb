# %%
import pandas as pd

# %%
d1 = pd.read_csv(r"S:\2026\08-Aug-26\01.08.26\30657885_BEINDATANEWRPT.CSV",engine='pyarrow')

# %%
d2 = pd.read_csv(r"S:\2026\08-Aug-26\01.08.26\30657885_BEINDATANEWRPT.CSV",usecols=['Customer Number', 'Customer Type',
        'End Date', 'Plan', 'Status', 'Decoder',
       'Item Description STB', 'Smart Card', 'Item Description SC'])

# %%
d2.columns
# Out:
# Index(['Customer Number', 'Customer Type', 'Entity', 'Contract Number',
#        'Start Date', 'End Date', 'Plan', 'Status', 'Decoder',
#        'Item Description STB', 'Smart Card', 'Item Description SC',
#        'Next Billing Date', 'Billing Cycle', 'PPV Balance', 'Customer Balance',
#        'Outstanding Balance'],
#       dtype='object')
