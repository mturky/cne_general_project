# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# df = pd.read_excel(r"C:\Users\mturky\Documents\june 2026 ind.xlsx")

data = pd.read_excel(r"C:\Users\mturky\Documents\june 2026 ind.xlsx", dtype='str')

# %%
data.iloc[647]['inv_Period From']
# Out:
# '2026-06-11 00:00:00'

# %%
display(df.iloc[[647]].T)
# Out:
#                                                    647
# inv_Subscriber Nr                             12456237
# inv_Doc Type                                   Invoice
# inv_Ftnr                                   INV_9010166
# inv_Created Date                   2026-06-11 00:00:00
# inv_Created Time                           01:00:42 AM
# inv_Doc Status                                  Posted
# inv_Period From                    2026-06-11 00:00:00
# inv_Period To                      2026-09-10 00:00:00
# inv_Amount                                         735
# inv_User Name                               Mobile_App
# inv_Default Entity Type                CNE Head Office
# inv_Smartcard                              42916908983
# inv_Bill Period                11/06/2026 - 10/09/2026
# inv_Bill Cycle                                      3M
# inv_Invoice Type                  Subscription Invoice
# inv_Plan Name                           TOGETHER 09.24
# ...

# %%
data.iloc[647]['inv_Period From']
# Out:
# '2026-05-15 00:00:00'

# %%
data['inv_Period From'] = pd.to_datetime(data['inv_Period From'])

# %%
display(df.iloc[[646]]['inv_Subscriber Nr'])
display(df.iloc[[647]])
# Out:
# 646    12454272
# Name: inv_Subscriber Nr, dtype: object
#     inv_Subscriber Nr inv_Doc Type     inv_Ftnr     inv_Created Date  \
# 647          12456237      Invoice  INV_9010166  2026-06-11 00:00:00
#
#     inv_Created Time inv_Doc Status      inv_Period From        inv_Period To  \
# 647      01:00:42 AM         Posted  2026-06-11 00:00:00  2026-09-10 00:00:00
#
#     inv_Amount inv_User Name inv_Default Entity Type inv_Smartcard  \
# 647        735    Mobile_App         CNE Head Office   42916908983
#
#              inv_Bill Period inv_Bill Cycle      inv_Invoice Type  \
# 647  11/06/2026 - 10/09/2026             3M  Subscription Invoice
#
#       inv_Plan Name inv_Contract Number       inv_Subscriber Type  \
# 647  TOGETHER 09.24             4246137  beIN Quartar Installment
#
#     inv_Subscriber Entity  pmt_Amount        pmt_Ftnr       Docinternalid  \
# 647       CNE Head office       735.0  CNEPMT_2343157  CNE_RCT_SW_2139435
#
# ...

# %%
df.loc[df['inv_Subscriber Nr']==12454272]
# Out:
#     inv_Subscriber Nr inv_Doc Type     inv_Ftnr     inv_Created Date  \
# 646          12454272      Invoice  INV_9023256  2026-06-12 00:00:00
#
#     inv_Created Time inv_Doc Status      inv_Period From        inv_Period To  \
# 646      12:30:37 AM         Posted  2026-06-16 00:00:00  2026-07-15 00:00:00
#
#     inv_Amount inv_User Name inv_Default Entity Type inv_Smartcard  \
# 646        507      SYSADMIN         CNE Head Office   42912476217
#
#              inv_Bill Period inv_Bill Cycle      inv_Invoice Type  \
# 646  16/06/2026 - 15/07/2026             1M  Subscription Invoice
#
#      inv_Plan Name inv_Contract Number inv_Subscriber Type  \
# 646  PREMIUM 09.24             3727777      BeIN sports CC
#
#     inv_Subscriber Entity  pmt_Amount        pmt_Ftnr       Docinternalid  \
# 646  Mohandeseen Showroom       507.0  CNEPMT_2348480  CNE_RCT_SW_2150535
#
#                        flag  inv_Bank Date inv_User Fullname  \
# ...
