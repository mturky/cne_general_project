# %%
import pandas as pd

# %%
data1 = pd.read_json(r"C:\Users\mturky\Desktop\hawary json\export-2025-09-29-1445-22926028-2983768829864284e1_1.json",dtype='str',lines=True, encoding='utf-8')
data2 = pd.read_json(r"C:\Users\mturky\Desktop\hawary json\export-2025-09-29-1438-22926028-298376554859706b80_1.json",dtype='str',lines=True, encoding='utf-8')

data3 = pd.read_json(r"C:\Users\mturky\Desktop\hawary json\export-2025-09-29-1445-22926028-2983768829864284e1_2.json",dtype='str',lines=True, encoding='utf-8')

data = pd.concat([data1,data2,data3])

# %%
data.columns
# Out:
# Index(['url', 'id', 'external_id', 'via', 'created_at', 'updated_at',
#        'generated_timestamp', 'type', 'subject', 'raw_subject', 'description',
#        'priority', 'status', 'follower_ids', 'email_cc_ids', 'forum_topic_id',
#        'problem_id', 'has_incidents', 'is_public', 'due_at', 'tags',
#        'custom_fields', 'satisfaction_rating', 'sharing_agreement_ids',
#        'custom_status_id', 'encoded_id', 'fields', 'followup_ids',
#        'ticket_form_id', 'brand_id', 'metric_set', 'dates',
#        'allow_channelback', 'allow_attachments', 'from_messaging_channel',
#        'submitter', 'requester', 'assignee', 'collaborator', 'recipient',
#        'group', 'organization', 'comments', 'name', 'email', 'time_zone',
#        'iana_time_zone', 'phone', 'shared_phone_number', 'photo', 'locale_id',
#        'locale', 'role', 'verified', 'alias', 'active', 'shared',
#        'shared_agent', 'last_login_at', 'two_factor_auth_enabled', 'signature',
# ...

# %%
data.to_csv('all_data_delete.csv', index= False)

# %%
data.loc[data['ticket_form_id']=='41503']
# Out:
# Empty DataFrame
# Columns: [url, id, external_id, via, created_at, updated_at, generated_timestamp, type, subject, raw_subject, description, priority, status, follower_ids, email_cc_ids, forum_topic_id, problem_id, has_incidents, is_public, due_at, tags, custom_fields, satisfaction_rating, sharing_agreement_ids, custom_status_id, encoded_id, fields, followup_ids, ticket_form_id, brand_id, metric_set, dates, allow_channelback, allow_attachments, from_messaging_channel, submitter, requester, assignee, collaborator, recipient, group, organization, comments, name, email, time_zone, iana_time_zone, phone, shared_phone_number, photo, locale_id, locale, role, verified, alias, active, shared, shared_agent, last_login_at, two_factor_auth_enabled, signature, details, notes, role_type, custom_role_id, moderator, ticket_restriction, only_private_comments, restricted_agent, suspended, default_group_id, report_csv, user_fields, abilities]
# Index: []
#
# [0 rows x 74 columns]

# %%
df = pd.DataFrame(data)
# df = df[['name','email','phone']]
df.to_csv(r"C:\Users\mturky\Desktop\hawary json\export-2025-09-30-0920-22926028-29857286923666847b_1.csv",index=False,encoding='utf-8-sig')
