# %%
import pandas as pd

# %%
nwagih = pd.read_excel(r"C:\Users\mturky\Desktop\comm wc.xlsx",dtype='str')
beindata = pd.read_csv(r"S:\09.06.26\30332043_BEINDATANEWRPT.CSV",dtype='str')

# %%
nwagih.columns
# Out:
# Index(['subnr'], dtype='object')

# %%
beindata.loc[beindata['Customer Number'].isin(nwagih['subnr'])].to_csv('comm_wc_result.csv', index=False)
