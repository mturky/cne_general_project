# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"S:\21.09.26\30951609_NEWCNEFINTRANSRPT.CSV", on_bad_lines='skip')
df.columns
# Out:
# C:\Users\mturky\AppData\Local\Temp\1\ipykernel_12196\3422738578.py:1: DtypeWarning: Columns (20,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"S:\21.09.26\30951609_NEWCNEFINTRANSRPT.CSV", on_bad_lines='skip')
# Index(['Subscriber Nr', 'Doc Type', 'Ftnr', 'Created Date', 'Created Time',
#        'Doc Status', 'Period From', 'Period To', 'Bank Date', 'Amount',
#        'User Name', 'User Fullname', 'Payment Ref No', 'Event Description',
#        'Payment Batch No', 'Batch Approval No', 'Default Entity Type',
#        'Collecting Entity', 'Pay Mode', 'Jv Type', 'Book Number', 'Smartcard',
#        'Bill Period', 'Bill Cycle', 'Invoice Type', 'Plan Name',
#        'Contract Number', 'Channel Provider', 'Subscriber Type',
#        'Subscriber Entity', 'Last Four Digits Of Card', 'PAYMENT_FLAG',
#        'DS_PAYMENT_FLAG'],
#       dtype='object')

# %%
df1= df.copy()
df1['Created Date'] = pd.to_datetime(df1['Created Date'],dayfirst=True)
df1
# Out:
#        Subscriber Nr     Doc Type          Ftnr Created Date Created Time  \
# 0           18944192  Credit Note     CR_733879   2026-01-01  03:07:04 PM
# 1           19231171   Debit Note     DR_733876   2026-01-01  03:02:08 PM
# 2           18942140   Debit Note     DR_733884   2026-01-01  03:51:07 PM
# 3           18913402   Debit Note     DR_733885   2026-01-01  04:00:46 PM
# 4           19065887   Debit Note     DR_733897   2026-01-01  04:40:48 PM
# ...              ...          ...           ...          ...          ...
# 840589      19189586      Payment  PYMT_4117058   2026-09-20  10:12:56 PM
# 840590      19184408      Payment  PYMT_4117061   2026-09-20  10:31:10 PM
# 840591      19080677      Payment  PYMT_4117067   2026-09-20  10:44:02 PM
# 840592       EDDMADI      Payment  PYMT_4117070   2026-09-20  10:57:18 PM
# 840593      18989133      Payment  PYMT_4117074   2026-09-20  11:08:44 PM
#
#        Doc Status Period From Period To Bank Date  Amount    User Name  \
# ...

# %%
df.loc[(df['Plan Name'].str.contains('2027',case=False,na=False)) & (df['Doc Status']=='Posted')]
# Out:
#        Subscriber Nr Doc Type         Ftnr         Created Date Created Time  \
# 8103        17560917  Invoice  INV_8675139  27-01-2026 00:00:00  06:12:39 PM
# 16837       19016170  Invoice  INV_8723115  22-02-2026 00:00:00  02:31:48 PM
# 19416       19233315  Invoice  INV_8740527  01-03-2026 00:00:00  02:33:28 PM
# 21194       18913129  Invoice  INV_8754085  06-03-2026 00:00:00  11:08:32 PM
# 21678       19185887  Invoice  INV_8757183  08-03-2026 00:00:00  11:24:53 AM
# ...              ...      ...          ...                  ...          ...
# 838764      17365094  Invoice  INV_9283991  15-09-2026 00:00:00  10:26:58 PM
# 839131      19166545  Invoice  INV_9284819  16-09-2026 00:00:00  01:08:47 PM
# 839140      19099216  Invoice  INV_9284930  16-09-2026 00:00:00  03:28:12 PM
# 839204      19079219  Invoice  INV_9285462  16-09-2026 00:00:00  09:43:20 PM
# 839862      19170719  Invoice  INV_9288488  19-09-2026 00:00:00  03:22:17 PM
#
# ...

# %%
df["Swap Datetime"] = pd.to_datetime(
            df["Swap Date"].str.split().str[0] + " " + df["Swap Time"],
            dayfirst=True
        )

# %%
19126641
