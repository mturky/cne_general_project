# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv(r"S:\Doaa 12.12.255\26659164_NEWCNEFINTRANSRPT.CSV",dtype = 'str')

# %%
data
# Out:
#       Subscriber Nr     Doc Type            Ftnr            Created Date  \
# 0          10341370  Credit Note       CR_408829  21/09/2025 12:00:00 AM
# 1          14008577  Credit Note       CR_408838  21/09/2025 12:00:00 AM
# 2          13294054  Credit Note       CR_408845  21/09/2025 12:00:00 AM
# 3          12832785  Credit Note       CR_408846  21/09/2025 12:00:00 AM
# 4          13927777  Credit Note       CR_408850  21/09/2025 12:00:00 AM
# ...             ...          ...             ...                     ...
# 15066      17308758      Payment  CNEPMT_2109927  21/09/2025 12:00:00 AM
# 15067       EDDSHRM      Payment  CNEPMT_2109930  21/09/2025 12:00:00 AM
# 15068       EDDKABA      Payment  CNEPMT_2109933  21/09/2025 12:00:00 AM
# 15069      16715984      Payment  CNEPMT_2109942  21/09/2025 12:00:00 AM
# 15070      11514173      Payment  CNEPMT_2109943  21/09/2025 12:00:00 AM
#
#       Created Time Doc Status Period From Period To Bank Date Amount  \
# ...

# %%
data = data.loc[~((data['Doc Type']=='Credit Note') & (data["Event Description"]=="HUMAX 1000s forced swap") )]

# %%
data
# Out:
#       Subscriber Nr    Doc Type            Ftnr            Created Date  \
# 1781       19185920  Debit Note       DR_408770  21/09/2025 12:00:00 AM
# 1782       18933524  Debit Note       DR_408798  21/09/2025 12:00:00 AM
# 1783       19141770     Invoice     INV_8308067  21/09/2025 12:00:00 AM
# 1784       19094284     Invoice     INV_8308072  21/09/2025 12:00:00 AM
# 1785       14418026     Invoice     INV_8308081  21/09/2025 12:00:00 AM
# ...             ...         ...             ...                     ...
# 15066      17308758     Payment  CNEPMT_2109927  21/09/2025 12:00:00 AM
# 15067       EDDSHRM     Payment  CNEPMT_2109930  21/09/2025 12:00:00 AM
# 15068       EDDKABA     Payment  CNEPMT_2109933  21/09/2025 12:00:00 AM
# 15069      16715984     Payment  CNEPMT_2109942  21/09/2025 12:00:00 AM
# 15070      11514173     Payment  CNEPMT_2109943  21/09/2025 12:00:00 AM
#
#       Created Time Doc Status             Period From               Period To  \
# ...
