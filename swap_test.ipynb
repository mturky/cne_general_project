# %%
import pandas as pd


swap = pd.read_csv(r"S:\13.08.26\30732615_SWAPRPT.CSV",dtype='str')

# %%
swap
# Out:
#       Subscriber Number           Subscriber Type     Received Entity  \
# 0              17459155            CNE Subscriber               Morad
# 1              18812340  beIN Quartar Installment              Domiat
# 2              18883014       beIN Bi Installment           beIN Alex
# 3              18678599            CNE Subscriber              Alex 5
# 4              16170769       beIN Bi Installment              Alex 3
# ...                 ...                       ...                 ...
# 63516          18166711  beIN Quartar Installment  beIN Gesr El Suies
# 63517          16270880  beIN Quartar Installment             Madinty
# 63518          16573665            CNE Subscriber             Madinty
# 63519          19151602            CNE Subscriber   beIN Ahmed Orabey
# 63520          13928271  beIN Quartar Installment            Ismailia
#
#       Replacement Number       Item Old Serial Number New Serial Number  \
# ...

# %%
swap = swap[['Subscriber Number', 'Old Serial Number','New Serial Number','Swap Date']]
swap = swap.rename (columns={'Subscriber Number':'Customer Number'})

# %%
swap
# Out:
#       Customer Number Old Serial Number New Serial Number  \
# 0            17459155       10137612601       10509181003
# 1            18812340       10508947289       10509036223
# 2            18883014        0351959325        0349765459
# 3            18678599       10509213780       10509134895
# 4            16170769       10355753566       10508840245
# ...               ...               ...               ...
# 63516        18166711        0315382471        0381368436
# 63517        16270880       10161623417       10739347341
# 63518        16573665        0315488929        0381360323
# 63519        19151602       10730870911       10738878411
# 63520        13928271        0303318719        0373011087
#
#                     Swap Date
# 0      12/05/2019 12:00:00 AM
# 1      13/05/2019 12:00:00 AM
# 2      13/05/2019 12:00:00 AM
# 3      15/05/2019 12:00:00 AM
# 4      16/05/2019 12:00:00 AM
# ...                       ...
# 63516  11/08/2026 12:00:00 AM
# ...
