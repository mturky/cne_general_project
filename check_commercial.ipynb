# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
nwagih = pd.read_excel(r"C:\Users\mturky\Documents\comm.xlsx",dtype='str')
ft = pd.read_csv(r"S:\06.07.26\30498243_NEWCNEFINTRANSRPT.CSV",dtype = 'str',on_bad_lines='warn')

# %%
n_ft = ft.loc[ft['Subscriber Nr'].isin(nwagih['File ##'])]

# %%
n_ft['Subscriber Type'].value_counts()
# Out:
# Subscriber Type
# Clubs                18068
# Muds                   974
# Hotels                 655
# Bein Companies PV      309
# Clubs Free              19
# beIN                     6
# Name: count, dtype: int64

# %%
my_ft = pd.read_csv(r"S:\playground\ftnew.csv", dtype='str')

# %%
n_ft = ft.loc[ft['Subscriber Nr'].isin(nwagih['File ##'])]

# %%
n_ft.loc[~n_ft['Subscriber Nr'].isin(my_ft['Subscriber Nr'])]

# %%
ft.columns

# %%
data = data.loc[data['Doc Type']=='Debit Note']
data['Created Date'] =

# %%
data.loc[data['Subscriber Nr']=='12198135']
